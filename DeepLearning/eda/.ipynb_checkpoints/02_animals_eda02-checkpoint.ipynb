# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import os
import sys
sys.path.insert(0, os.path.abspath('../'))
import rhplib.datasets_pandas

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#load data from a CSV
dataset = pd.read_csv('../../datasets/animals.csv', header=0, sep=';')
print(dataset.head())
# Out:
#       name  Has legs  Can swim  Has gills  breathes  lives in the water
# 0      Dog         1         1          0         1                   0
# 1      Cat         1         0          0         1                   0
# 2    Mouse         1         1          0         1                   0
# 3  Sardine         0         1          1         0                   1
# 4      Man         1         1          0         1                   0

# %%
# Histogram of features
rhplib.datasets_pandas.plot_hist_dataset(dataset,2,2,False)
# Out:
# total_rows= 22
# total_cols= 6

# %%
"""
In this dataset, the boxplot are not very useful, due to the nature of the data.
"""
for c in dataset.columns:
    if c not in ['name','lives in the water']:
        fig = plt.figure()
        sns.boxplot(dataset[c])
        plt.title(c)
