# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import os
import sys
sys.path.insert(0, os.path.abspath('../'))
import rhplib.datasets_pandas

# %%
#load data from a CSV
dataset = pd.read_csv('../../datasets/animals.csv', header=0, sep=';')
print(dataset.head())
# Out:
#       name  Has legs  Can swim  Has gills  breathes  lives in the water
# 0      Dog         1         1          0         1                   0
# 1      Cat         1         0          0         1                   0
# 2    Mouse         1         1          0         1                   0
# 3  Sardine         0         1          1         0                   1
# 4      Man         1         1          0         1                   0

# %%
# Histogram of features
rhplib.datasets_pandas.plot_hist_dataset(dataset,2,False)

# %%
"""
In this dataset, the boxplot are not very useful, due to the nature of the data.
"""
for c in dataset.columns:
    if c not in ['name','lives in the water']:
        fig = plt.figure()
        sns.boxplot(dataset[c])
        plt.title(c)
# Out:
# /home/rhp/MyDevTools/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/rhp/MyDevTools/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/rhp/MyDevTools/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/rhp/MyDevTools/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
