# %%
"""
Author: rui.humberto.pereira@gmail.com
Date: 2021/Mai/11
Updated: 2021/Mai/12
"""
# Out:
# '\nAuthor: rui.humberto.pereira@gmail.com\nDate: 2021/Mai/11\nUpdated: 2021/Mai/12\n'

# %%
#The necessary libs
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#include rhplib
import os
import sys
sys.path.insert(0, os.path.abspath('../'))
import rhplib.datasets_pandas

# %%
#Desable the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# load Pima Indians Diabetes dataset using pandas
dataset = pd.read_csv('../../datasets/winequality-red.csv',delimiter=',',header=0)
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Check the existance of null values
dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Remove the invalid data
#Todo

# %%
# Clean the outliers
# Note that when you clean one feature the fences of the others are influenced!
dataset=rhplib.datasets_pandas.clean_iqr_outliers(dataset,'citric acid',True)
dataset=rhplib.datasets_pandas.clean_iqr_outliers(dataset,'chlorides',True)
dataset=rhplib.datasets_pandas.clean_iqr_outliers(dataset,'free sulfur dioxide',True)
dataset=rhplib.datasets_pandas.clean_iqr_outliers(dataset,'total sulfur dioxide',True)
dataset=rhplib.datasets_pandas.clean_iqr_outliers(dataset,'residual sugar',True)
# Out:
# Eliminating the outliers of citric acid  irq=0.330  [-0.405 ... 0.915]
# Before:  1599
# After data cleaning:  1598
# Eliminating the outliers of chlorides  irq=0.020  [0.040 ... 0.120]
# Before:  1598
# After data cleaning:  1487
# Eliminating the outliers of free sulfur dioxide  irq=13.000  [-11.500 ... 40.500]
# Before:  1487
# After data cleaning:  1457
# Eliminating the outliers of total sulfur dioxide  irq=38.000  [-35.000 ... 117.000]
# Before:  1457
# After data cleaning:  1396
# Eliminating the outliers of residual sugar  irq=0.700  [0.850 ... 3.650]
# Before:  1396
# After data cleaning:  1275

# %%
rhplib.datasets_pandas.analysis_graph_dataset(dataset,'quality','Wine Quality')
